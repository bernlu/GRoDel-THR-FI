# %%
import simexpal
import re
import pandas as pd
import numpy as np
import networkit as nk

# %%
# load simex results

def parse(run, f):
    res = {}
    res['status'] = run.get_status().name
    res['experiment'] = run.experiment.name
    res['instance'] = run.instance.shortname
    res['run'] = run
    res['revision'] = run.experiment.revision.name
    for var in run.experiment.variation:
        res[var.axis] = var.name
    
    if run.experiment.name == 'harmonicResistanceGreedy' and run.get_status().name != "FINISHED":
        with open(run.aux_file_path('stderr')) as aux_file:
            for line in aux_file.readlines():
                if 'starting greedy round 0' in line:
                    print(run.instance.shortname, 'greedy start found')
    
    if 'ExactSolution' in run.experiment.name:
        for line in f.readlines():
            if line.startswith('time:'):
                res['time'] = line[7:-1]
            if line.startswith('best edges:'):
                edges = re.findall(r'\(\s?(\d+),\s?(\d+)\)', line)
                res['edges'] = [(int(e[0]), int(e[1])) for e in edges]
    else:
        for line in f.readlines():
            if line.startswith('Running time:'):
                res['time'] = line[14:-1]
            if line.startswith('time:'):
                res['time'] = line[7:-1]
            if line.startswith('Result edges:') or line.startswith('items:'):
                edges = re.findall(r'\(\s?(\d+),\s?(\d+)\)', line)
                res['edges'] = [(int(e[0]), int(e[1])) for e in edges]
    return res

# load all results
cfg = simexpal.config_for_dir('/work/berneluk/harmonic-resistance-experiments/experiments')
results = []
for run in cfg.discover_all_runs():
    if run.get_status() == simexpal.base.Status.NOT_SUBMITTED: continue
    try:
        with run.open_output_file() as f:
            results.append(parse(run, f))
    except RuntimeError as e:
        pass
        # print('could not open file for run', e, 'run status:', run.get_status())

results = pd.DataFrame(results)
pd.reset_option('display.max_rows')

# dataframe types
results['status'] = results['status'].astype('category')
results['experiment'] = results['experiment'].astype('category')
results['instance'] = results['instance'].astype('category')
results['time'] = pd.to_timedelta(results['time'])
results
# Out:
#        status                experiment        instance  \
# 0    FINISHED  forestIndexExactSolution             ba1
# 1    FINISHED  forestIndexExactSolution             ba2
# 2    FINISHED  forestIndexExactSolution             ba3
# 3    FINISHED  forestIndexExactSolution   disturbedRing
# 4    FINISHED  forestIndexExactSolution         grid5x3
# ..        ...                       ...             ...
# 104  FINISHED  harmonicResistanceGreedy         grid5x3
# 105   STARTED  harmonicResistanceGreedy  p2p-Gnutella04
# 106   STARTED  harmonicResistanceGreedy  p2p-Gnutella09
# 107   STARTED  harmonicResistanceGreedy   web-indochina
# 108   STARTED  harmonicResistanceGreedy       wiki-Vote
#
#                                               run  \
# 0    <simexpal.base.Run object at 0x7fcb0e0bba10>
# 1    <simexpal.base.Run object at 0x7fcb0e0b8090>
# 2    <simexpal.base.Run object at 0x7fcb0e0bb750>
# 3    <simexpal.base.Run object at 0x7fcb0e0bbe50>
# 4    <simexpal.base.Run object at 0x7fcb0e0bbe10>
# ..                                            ...
# 104  <simexpal.base.Run object at 0x7fcb0fa89ed0>
# 105  <simexpal.base.Run object at 0x7fcb0fa88210>
# 106  <simexpal.base.Run object at 0x7fcb0fa88a90>
# 107  <simexpal.base.Run object at 0x7fcb0fa8add0>
# 108  <simexpal.base.Run object at 0x7fcb0fa8a450>
#
#                             revision     k  \
# 0                  networkit-py-main   k-5
# 1                  networkit-py-main   k-5
# 2                  networkit-py-main   k-5
# 3                  networkit-py-main   k-5
# 4                  networkit-py-main   k-5
# ..                               ...   ...
# 104  harmonicResistance-parallelLamg  k-25
# 105  harmonicResistance-parallelLamg  k-25
# 106  harmonicResistance-parallelLamg  k-25
# 107  harmonicResistance-parallelLamg  k-25
# 108  harmonicResistance-parallelLamg  k-25
#
#                                                  edges                   time
# 0       [(1, 13), (2, 16), (5, 16), (6, 13), (11, 13)] 0 days 00:22:13.783533
# 1      [(0, 13), (5, 12), (8, 13), (10, 12), (12, 13)] 0 days 00:21:55.635820
# 2       [(1, 17), (3, 10), (5, 10), (6, 10), (10, 17)] 0 days 00:22:45.375821
# 3             [(0, 1), (0, 8), (1, 2), (6, 7), (7, 8)] 0 days 00:00:00.103583
# 4          [(0, 1), (0, 5), (5, 6), (5, 10), (10, 11)] 0 days 00:00:12.223374
# ..                                                 ...                    ...
# 104  [(12, 11), (2, 1), (13, 12), (3, 2), (7, 6), (... 0 days 00:00:00.019000
# 105                                                NaN                    NaT
# 106                                                NaN                    NaT
# 107                                                NaN                    NaT
# 108                                                NaN                    NaT
#
# [109 rows x 8 columns]

# %%
results.query('experiment == "harmonicResistanceGreedy" and status == "FINISHED"')
# Out:
#        status                experiment           instance  \
# 95   FINISHED  harmonicResistanceGreedy           Bcspwr10
# 98   FINISHED  harmonicResistanceGreedy          EmailUniv
# 104  FINISHED  harmonicResistanceGreedy                ba1
# 105  FINISHED  harmonicResistanceGreedy                ba2
# 106  FINISHED  harmonicResistanceGreedy                ba3
# 108  FINISHED  harmonicResistanceGreedy      disturbedRing
# 110  FINISHED  harmonicResistanceGreedy            grid5x3
# 111  FINISHED  harmonicResistanceGreedy            grid5x6
# 112  FINISHED  harmonicResistanceGreedy            grid7x4
# 113  FINISHED  harmonicResistanceGreedy          hotdog5x6
# 115  FINISHED  harmonicResistanceGreedy          inf-power
# 119  FINISHED  harmonicResistanceGreedy           web-spam
# 122  FINISHED  harmonicResistanceGreedy                ws1
# 123  FINISHED  harmonicResistanceGreedy                ws2
# 124  FINISHED  harmonicResistanceGreedy                ws3
# 126  FINISHED  harmonicResistanceGreedy           Erdos992
# 127  FINISHED  harmonicResistanceGreedy            Reality
# 128  FINISHED  harmonicResistanceGreedy  airTrafficControl
# 129  FINISHED  harmonicResistanceGreedy           euroroad
# 131  FINISHED  harmonicResistanceGreedy            grid5x3
#
#                                               run  \
# 95   <simexpal.base.Run object at 0x7fcb0fab8290>
# 98   <simexpal.base.Run object at 0x7fcb0fabaa50>
# 104  <simexpal.base.Run object at 0x7fcb0fab8c90>
# 105  <simexpal.base.Run object at 0x7fcb0fabaa10>
# 106  <simexpal.base.Run object at 0x7fcb0fab9450>
# 108  <simexpal.base.Run object at 0x7fcb0fab9510>
# 110  <simexpal.base.Run object at 0x7fcb0fab83d0>
# 111  <simexpal.base.Run object at 0x7fcb0fabad50>
# 112  <simexpal.base.Run object at 0x7fcb0fab82d0>
# 113  <simexpal.base.Run object at 0x7fcb0fab8310>
# 115  <simexpal.base.Run object at 0x7fcb0fabbed0>
# 119  <simexpal.base.Run object at 0x7fcb0fab9cd0>
# 122  <simexpal.base.Run object at 0x7fcb0faba250>
# 123  <simexpal.base.Run object at 0x7fcb0fab9b50>
# 124  <simexpal.base.Run object at 0x7fcb0faba610>
# 126  <simexpal.base.Run object at 0x7fcb0fabb2d0>
# 127  <simexpal.base.Run object at 0x7fcb0fab8990>
# 128  <simexpal.base.Run object at 0x7fcb0fabbe50>
# 129  <simexpal.base.Run object at 0x7fcb0fabaad0>
# 131  <simexpal.base.Run object at 0x7fcb0fabbd10>
#
#                             revision     k  \
# 95           harmonicResistance-main  k-25
# 98           harmonicResistance-main  k-25
# 104          harmonicResistance-main  k-25
# 105          harmonicResistance-main  k-25
# 106          harmonicResistance-main  k-25
# 108          harmonicResistance-main  k-25
# 110          harmonicResistance-main  k-25
# 111          harmonicResistance-main  k-25
# 112          harmonicResistance-main  k-25
# 113          harmonicResistance-main  k-25
# 115          harmonicResistance-main  k-25
# 119          harmonicResistance-main  k-25
# 122          harmonicResistance-main  k-25
# 123          harmonicResistance-main  k-25
# 124          harmonicResistance-main  k-25
# 126  harmonicResistance-parallelLamg  k-25
# 127  harmonicResistance-parallelLamg  k-25
# 128  harmonicResistance-parallelLamg  k-25
# 129  harmonicResistance-parallelLamg  k-25
# 131  harmonicResistance-parallelLamg  k-25
#
#                                                  edges                   time
# 95   [(4675, 719), (5056, 719), (4103, 2517), (5201... 0 days 08:11:35.933000
# 98   [(513, 64), (997, 426), (767, 185), (996, 422)... 0 days 00:45:20.494000
# 104  [(11, 9), (16, 15), (16, 5), (7, 6), (17, 1), ... 0 days 00:00:00.027000
# 105  [(13, 12), (15, 9), (13, 8), (11, 7), (16, 11)... 0 days 00:00:00.026000
# 106  [(17, 10), (17, 9), (7, 4), (15, 12), (10, 3),... 0 days 00:00:00.050000
# 108  [(3, 2), (7, 6), (2, 1), (8, 7), (1, 0), (8, 0... 0 days 00:00:00.029000
# 110  [(12, 11), (2, 1), (13, 12), (3, 2), (7, 6), (... 0 days 00:00:00.063000
# 111  [(19, 14), (15, 10), (24, 19), (20, 15), (14, ... 0 days 00:00:00.204000
# 112  [(24, 23), (3, 2), (25, 24), (4, 3), (26, 25),... 0 days 00:00:00.227000
# 113  [(19, 14), (15, 10), (27, 26), (2, 1), (28, 27... 0 days 00:00:00.618000
# 115  [(2823, 558), (373, 321), (1677, 1377), (1379,... 1 days 02:39:00.060000
# 119  [(2946, 1884), (512, 156), (3627, 959), (3527,... 4 days 03:10:56.614000
# 122  [(15, 9), (15, 14), (10, 8), (14, 4), (7, 4), ... 0 days 00:00:00.025000
# 123  [(14, 13), (13, 5), (14, 8), (14, 12), (13, 2)... 0 days 00:00:00.022000
# 124  [(13, 11), (5, 0), (13, 2), (3, 2), (13, 5), (... 0 days 00:00:00.025000
# 126  [(303, 102), (2446, 185), (189, 24), (335, 18)... 0 days 06:28:02.225000
# 127  [(235, 37), (99, 68), (5010, 62), (788, 10), (... 0 days 08:50:06.974000
# 128  [(759, 659), (1028, 237), (737, 258), (462, 46... 0 days 00:06:31.988000
# 129  [(726, 334), (262, 249), (758, 757), (758, 249... 0 days 00:14:58.897000
# 131  [(12, 11), (2, 1), (13, 12), (3, 2), (7, 6), (... 0 days 00:00:00.019000

# %%
def centralityScore(row: pd.Series):
    graph = nk.readGraph(row.run.instance.fullpath)
    cc = nk.centrality.Closeness(graph, False, nk.centrality.ClosenessVariant.GENERALIZED)
    cc.run()
    nodePercentiles = {}
    prevBcValue = None
    prevNode = None
    numSeen = -1
    numCurrent = 0
    for node, bcValue in reversed(cc.ranking()):
        if prevBcValue and abs(prevBcValue - bcValue) < 1e-6:
            nodePercentiles[node] = nodePercentiles[prevNode]
            numCurrent = numCurrent + 1
        else:
            numSeen = numSeen + numCurrent + 1
            numCurrent = 0
            nodePercentiles[node] = numSeen/graph.numberOfNodes()
            prevBcValue = bcValue
            prevNode = node

    centralities = []
    for edge in row.edges:
        centralities.append(np.mean((nodePercentiles[edge[0]], nodePercentiles[edge[1]])))

    return np.mean(centralities)

# %%
results['score'] = results.query('status=="FINISHED" and (experiment=="harmonicResistanceGreedy" or experiment == "forestIndexGreedy")').apply(centralityScore, axis=1)

# %%
def filterBothFinished(group):
    if np.any(group.experiment == 'harmonicResistanceGreedy'):
        return group

filteredResults = results.query('status=="FINISHED" and (experiment=="harmonicResistanceGreedy" or experiment == "forestIndexGreedy") and revision != "forestIndex-via-resistance-full-search"').groupby('instance').apply(filterBothFinished)
filteredResults.query('instance not in ("ba1", "ba2", "ba3", "ws1", "ws2", "ws3", "grid5x3", "grid5x6", "grid7x4", "hotdog5x6", "disturbedRing")')[["experiment", "revision", "time", "score"]]
# Out:
# /tmp/ipykernel_536191/3068064016.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filteredResults = results.query('status=="FINISHED" and (experiment=="harmonicResistanceGreedy" or experiment == "forestIndexGreedy") and revision != "forestIndex-via-resistance-full-search"').groupby('instance').apply(filterBothFinished)
# /tmp/ipykernel_536191/3068064016.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   filteredResults = results.query('status=="FINISHED" and (experiment=="harmonicResistanceGreedy" or experiment == "forestIndexGreedy") and revision != "forestIndex-via-resistance-full-search"').groupby('instance').apply(filterBothFinished)
#                                      experiment  \
# instance
# Bcspwr10          16          forestIndexGreedy
#                   95   harmonicResistanceGreedy
# EmailUniv         19          forestIndexGreedy
#                   98   harmonicResistanceGreedy
# Erdos992          20          forestIndexGreedy
#                   126  harmonicResistanceGreedy
# Reality           23          forestIndexGreedy
#                   127  harmonicResistanceGreedy
# airTrafficControl 24          forestIndexGreedy
#                   128  harmonicResistanceGreedy
# euroroad          31          forestIndexGreedy
#                   129  harmonicResistanceGreedy
# inf-power         38          forestIndexGreedy
#                   115  harmonicResistanceGreedy
# web-spam          42          forestIndexGreedy
#                   119  harmonicResistanceGreedy
#
#                                               revision                   time  \
# instance
# Bcspwr10          16        forestIndex-via-resistance 0 days 00:00:01.786816
#                   95           harmonicResistance-main 0 days 08:11:35.933000
# EmailUniv         19        forestIndex-via-resistance 0 days 00:00:00.159011
#                   98           harmonicResistance-main 0 days 00:45:20.494000
# Erdos992          20        forestIndex-via-resistance 0 days 00:00:01.180637
#                   126  harmonicResistance-parallelLamg 0 days 06:28:02.225000
# Reality           23        forestIndex-via-resistance 0 days 00:00:03.758507
#                   127  harmonicResistance-parallelLamg 0 days 08:50:06.974000
# airTrafficControl 24        forestIndex-via-resistance 0 days 00:00:00.110273
#                   128  harmonicResistance-parallelLamg 0 days 00:06:31.988000
# euroroad          31        forestIndex-via-resistance 0 days 00:00:00.059621
#                   129  harmonicResistance-parallelLamg 0 days 00:14:58.897000
# inf-power         38        forestIndex-via-resistance 0 days 00:00:01.053373
#                   115          harmonicResistance-main 1 days 02:39:00.060000
# web-spam          42        forestIndex-via-resistance 0 days 00:00:02.542473
#                   119          harmonicResistance-main 4 days 03:10:56.614000
#
#                           score
# instance
# Bcspwr10          16   0.301728
#                   95   0.740547
# EmailUniv         19   0.526037
#                   98   0.405384
# Erdos992          20   0.691134
#                   126  0.643315
# Reality           23   0.508321
#                   127  0.825954
# airTrafficControl 24   0.063752
#                   128  0.579380
# euroroad          31   0.160077
#                   129  0.661694
# inf-power         38   0.257535
#                   115  0.858150
# web-spam          42   0.039274
#                   119  0.457516

# %%
filteredResults.query('instance not in ("ba1", "ba2", "ba3", "ws1", "ws2", "ws3", "grid5x3", "grid5x6", "grid7x4", "hotdog5x6", "disturbedRing")')[["experiment", "score", "time"]]
# Out:
#                                      experiment     score  \
# instance
# Bcspwr10          16          forestIndexGreedy  0.301728
#                   95   harmonicResistanceGreedy  0.740547
# EmailUniv         19          forestIndexGreedy  0.526037
#                   98   harmonicResistanceGreedy  0.405384
# Erdos992          20          forestIndexGreedy  0.691134
#                   126  harmonicResistanceGreedy  0.643315
# Reality           23          forestIndexGreedy  0.508321
#                   127  harmonicResistanceGreedy  0.825954
# airTrafficControl 24          forestIndexGreedy  0.063752
#                   128  harmonicResistanceGreedy  0.579380
# euroroad          31          forestIndexGreedy  0.160077
#                   129  harmonicResistanceGreedy  0.661694
# inf-power         38          forestIndexGreedy  0.257535
#                   115  harmonicResistanceGreedy  0.858150
# web-spam          42          forestIndexGreedy  0.039274
#                   119  harmonicResistanceGreedy  0.457516
#
#                                         time
# instance
# Bcspwr10          16  0 days 00:00:01.786816
#                   95  0 days 08:11:35.933000
# EmailUniv         19  0 days 00:00:00.159011
#                   98  0 days 00:45:20.494000
# Erdos992          20  0 days 00:00:01.180637
#                   126 0 days 06:28:02.225000
# Reality           23  0 days 00:00:03.758507
#                   127 0 days 08:50:06.974000
# airTrafficControl 24  0 days 00:00:00.110273
#                   128 0 days 00:06:31.988000
# euroroad          31  0 days 00:00:00.059621
#                   129 0 days 00:14:58.897000
# inf-power         38  0 days 00:00:01.053373
#                   115 1 days 02:39:00.060000
# web-spam          42  0 days 00:00:02.542473
#                   119 4 days 03:10:56.614000
